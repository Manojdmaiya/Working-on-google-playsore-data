# %%
import  numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv("googleplaystore.csv")

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
imputer = SimpleImputer(missing_values=np.nan,strategy='mean')
imputer.fit(df.iloc[:,2:3].values)
df.iloc[:,2:3] = imputer.transform(df.iloc[:,2:3].values)
df=df.dropna()

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# ## Q1.How many free apps are there in ART_AND_DESIGN

# %%
df.values
# Out:
# array([['Photo Editor & Candy Camera & Grid & ScrapBook',
#         'ART_AND_DESIGN', 4.1, ..., 'January 7, 2018', '1.0.0',
#         '4.0.3 and up'],
#        ['Coloring book moana', 'ART_AND_DESIGN', 3.9, ...,
#         'January 15, 2018', '2.0.0', '4.0.3 and up'],
#        ['U Launcher Lite – FREE Live Cool Themes, Hide Apps',
#         'ART_AND_DESIGN', 4.7, ..., 'August 1, 2018', '1.2.4',
#         '4.0.3 and up'],
#        ...,
#        ['Parkinson Exercices FR', 'MEDICAL', 4.193338315362443, ...,
#         'January 20, 2017', '1.0', '2.2 and up'],
#        ['The SCP Foundation DB fr nn5n', 'BOOKS_AND_REFERENCE', 4.5, ...,
#         'January 19, 2015', 'Varies with device', 'Varies with device'],
#        ['iHoroscope - 2018 Daily Horoscope & Astrology', 'LIFESTYLE',
#         4.5, ..., 'July 25, 2018', 'Varies with device',
#         'Varies with device']], dtype=object)

# %%
df.values.shape
# Out:
# (10829, 13)

# %%
df = df.values

# %%
df
# Out:
# array([['Photo Editor & Candy Camera & Grid & ScrapBook',
#         'ART_AND_DESIGN', 4.1, ..., 'January 7, 2018', '1.0.0',
#         '4.0.3 and up'],
#        ['Coloring book moana', 'ART_AND_DESIGN', 3.9, ...,
#         'January 15, 2018', '2.0.0', '4.0.3 and up'],
#        ['U Launcher Lite – FREE Live Cool Themes, Hide Apps',
#         'ART_AND_DESIGN', 4.7, ..., 'August 1, 2018', '1.2.4',
#         '4.0.3 and up'],
#        ...,
#        ['Parkinson Exercices FR', 'MEDICAL', 4.193338315362443, ...,
#         'January 20, 2017', '1.0', '2.2 and up'],
#        ['The SCP Foundation DB fr nn5n', 'BOOKS_AND_REFERENCE', 4.5, ...,
#         'January 19, 2015', 'Varies with device', 'Varies with device'],
#        ['iHoroscope - 2018 Daily Horoscope & Astrology', 'LIFESTYLE',
#         4.5, ..., 'July 25, 2018', 'Varies with device',
#         'Varies with device']], dtype=object)

# %%
df[0]
# Out:
# array(['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN',
#        4.1, '159', '19M', '10,000+', 'Free', '0', 'Everyone',
#        'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up'],
#       dtype=object)

# %%
for i in df:
    print(i[0],i[6])
    break
# Out:
# Photo Editor & Candy Camera & Grid & ScrapBook Free

# %%
c=0
for i in df:
    if(i[1]=='ART_AND_DESIGN' and i[6]=='Free'):
        c+=1
print("There are ",c," free apps from art and design ")
# Out:
# There are  61  free apps from art and design

# %%
d=0
for i in df:
    if(i[1]=='ART_AND_DESIGN' and i[6]=='Paid'):
        d+=1
print("There are ",d," paid apps from art and design ")
# Out:
# There are  3  paid apps from art and design

# %% [markdown]
# ## Q2.How many apps are there in art and design category with rating  more than 4.5

# %%
d=0
for i in df:
    if(i[1]=='ART_AND_DESIGN' and i[2]>4.5):
        d+=1
print("There are ",d,'apps in art and design category with rating greater than 4.5')
# Out:
# There are  22 apps in art and design category with rating greater than 4.5

# %% [markdown]
# ## Q3.How many apps are there in FAMILY with rating greater than 4.5 and Free?

# %%
d=0
for i in df:
    if(i[1]=='FAMILY' and i[2]>4.5 and i[6]=='Free'):
        d+=1
print("There are ",d,'apps in art and design category with rating greater than 4.5 and free')
# Out:
# There are  314 apps in art and design category with rating greater than 4.5 and free

# %% [markdown]
# ## Q4. List all the free apps with rating more then 4.5 and category is FAMILY?

# %%
print('*'*100)
print("  Thses are the free apps in the FAMILY category with rating greater than 4.5 ")
print('*'*100)
d=0
for i in df:
    if(i[1]=='FAMILY' and i[2]>4.5 and i[6]=='Free'):
        print(i[0])
print('-'*100)
# Out:
# ****************************************************************************************************
#   Thses are the free apps in the FAMILY category with rating greater than 4.5
# ****************************************************************************************************
# Super ABC! Learning games for kids! Preschool apps
# Candy Pop Story
# Dog Run - Pet Dog Simulator
# Puzzle Kids - Animals Shapes and Jigsaw Puzzles
# No. Color - Color by Number, Number Coloring
# Garden Fruit Legend
# Piano Kids - Music & Songs
# Duolingo: Learn Languages Free
# Super ABC! Learning games for kids! Preschool apps
# Drawing for Kids Learning Games for Toddlers age 3
# Baby ABC in box! Kids alphabet games for toddlers!
# Henry Danger Crime Warp
# Fruit Cube Blast
# Toddler Kids Puzzles PUZZINGO
# Fuzzy Seasons: Animal Forest
# Dog Run - Pet Dog Simulator
# My Oasis - Calming and Relaxing Idle Clicker Game
# Ninja Dash - Ronin Jump RPG
# Monster High™ Minis Mania
# Monica Toy TV
# ...

# %% [markdown]
# ## Q1. How many free apps are there in art and design?

# %%
df_pr=df[df['Category']=='ART_AND_DESIGN']

# %%
df_pr
# Out:
#                                                     App        Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                   Coloring book moana  ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint  ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ...                                                 ...             ...
# 7174                            Easy DIY CD Craft Ideas  ART_AND_DESIGN
# 8679                                       Dp for girls  ART_AND_DESIGN
# 8712             Name Art DP - Focus n Filter Text 2018  ART_AND_DESIGN
# 8871                             Test Application DT 02  ART_AND_DESIGN
# 8888            Spring flowers theme couleurs d t space  ART_AND_DESIGN
#
#         Rating Reviews  Size     Installs  Type Price Content Rating  \
# ...

# %%
df_pr=df[df['Category']=='BOOKS_AND_REFERENCE']

# %%
df_pr
# Out:
#                                       App             Category  Rating  \
# 139                  Wattpad 📖 Free Books  BOOKS_AND_REFERENCE     4.6
# 140      E-Book Read - Read Book for free  BOOKS_AND_REFERENCE     4.5
# 141    Download free book with green book  BOOKS_AND_REFERENCE     4.6
# 142                             Wikipedia  BOOKS_AND_REFERENCE     4.4
# 143                         Amazon Kindle  BOOKS_AND_REFERENCE     4.2
# ...                                   ...                  ...     ...
# 10815           Golden Dictionary (FR-AR)  BOOKS_AND_REFERENCE     4.2
# 10819                           Fanfic-FR  BOOKS_AND_REFERENCE     3.3
# 10829      Bulgarian French Dictionary Fr  BOOKS_AND_REFERENCE     4.6
# 10833                         Chemin (fr)  BOOKS_AND_REFERENCE     4.8
# 10839       The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE     4.5
#
#        Reviews                Size      Installs  Type Price Content Rating  \
# ...

# %%
print(len(df_pr[df_pr['Type']=='Free']))
# Out:
# 61

# %% [markdown]
# ## Q2. How many apps are there in ART_AND_DESIGN with rating more than 4.5?

# %%
df_pr=df[df['Category']=='ART_AND_DESIGN']
print(len(df_pr[df_pr['Rating']>4.5]))
# Out:
# 22

# %% [markdown]
# ## Q3. How many apps are there in FAMILY with rating more than 4.5 and Free?

# %%
df_ar=df[df['Category']=='FAMILY']

# %%
df_ar=df_ar[df_ar['Type']=='Free']

# %%
print(len(df_ar[df_ar['Rating']>4.5]))
# Out:
# 314

# %% [markdown]
# ## Q4. List all the free apps with rating more than 4.5 and category is FAMILY?

# %%
df_ar=df[df['Category']=='FAMILY']
df_ar=df_ar[df_ar['Rating']>4.5]

result = df_ar[df_ar['Type']=='Free'].values
for i in result:
    print(i[0])
# Out:
# Super ABC! Learning games for kids! Preschool apps
# Candy Pop Story
# Dog Run - Pet Dog Simulator
# Puzzle Kids - Animals Shapes and Jigsaw Puzzles
# No. Color - Color by Number, Number Coloring
# Garden Fruit Legend
# Piano Kids - Music & Songs
# Duolingo: Learn Languages Free
# Super ABC! Learning games for kids! Preschool apps
# Drawing for Kids Learning Games for Toddlers age 3
# Baby ABC in box! Kids alphabet games for toddlers!
# Henry Danger Crime Warp
# Fruit Cube Blast
# Toddler Kids Puzzles PUZZINGO
# Fuzzy Seasons: Animal Forest
# Dog Run - Pet Dog Simulator
# My Oasis - Calming and Relaxing Idle Clicker Game
# Ninja Dash - Ronin Jump RPG
# Monster High™ Minis Mania
# Monica Toy TV
# Sworkit Kids - Fitness Meets Fun
# Crazy Colors: Bubbles Matching
# Pino chess
# Duolingo: Learn Languages Free
# Animal Jam - Play Wild!
# Dog Sim Online: Raise a Family
# Color by Number - Draw Sandbox Pixel Art
# Build a Bridge!
# Find a Way: Addictive Puzzle
# CompTIA Exam Training
# ...

# %% [markdown]
# ## Q1.Group by function using Pandas

# %% [markdown]
# ### Name the apps that are in art and design with rating 4.5 in ascending order w.r.to ratings?

# %%
df_pr=df[df['Category']=='ART_AND_DESIGN']
df_pr=df_pr[df_pr['Rating']>4.5]

df_pr.sort_values(by='Rating',ascending = True).head()
# Out:
#                                                     App        Category  \
# 13                                Mandala Coloring Book  ART_AND_DESIGN
# 19                                         ibis Paint X  ART_AND_DESIGN
# 46    Install images with music to make video withou...  ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 4764     X Launcher Prime: With OS Style Theme & No Ads  ART_AND_DESIGN
#
#       Rating Reviews  Size     Installs  Type  Price Content Rating  \
# 13       4.6    4326   21M     100,000+  Free      0       Everyone
# 19       4.6  224399   31M  10,000,000+  Free      0       Everyone
# 46       4.6    1070   26M     100,000+  Free      0       Everyone
# 2        4.7   87510  8.7M   5,000,000+  Free      0       Everyone
# 4764     4.7     149  3.5M       1,000+  Paid  $1.99       Everyone
#
#             Genres       Last Updated Current Ver   Android Ver
# ...

# %% [markdown]
# ## Q2. Which category is having maximum average rating Descending order?

# %%
df.groupby('Category').mean()['Rating'].sort_values(ascending = False)
# Out:
# Category
# EDUCATION              4.387778
# ART_AND_DESIGN         4.368438
# EVENTS                 4.363647
# BOOKS_AND_REFERENCE    4.311537
# PERSONALIZATION        4.306873
# GAME                   4.282506
# PARENTING              4.282223
# HEALTH_AND_FITNESS     4.266296
# BEAUTY                 4.260882
# SHOPPING               4.254052
# SOCIAL                 4.248001
# WEATHER                4.239675
# SPORTS                 4.218404
# PRODUCTIVITY           4.208287
# HOUSE_AND_HOME         4.196819
# FAMILY                 4.192490
# PHOTOGRAPHY            4.192179
# AUTO_AND_VEHICLES      4.190824
# MEDICAL                4.190167
# LIBRARIES_AND_DEMO     4.182938
# FOOD_AND_DRINK         4.170709
# COMMUNICATION          4.163842
# COMICS                 4.156445
# BUSINESS               4.145987
# NEWS_AND_MAGAZINES     4.142993
# FINANCE                4.139108
# ENTERTAINMENT          4.126174
# TRAVEL_AND_LOCAL       4.119716
# LIFESTYLE              4.112427
# ...

# %% [markdown]
# ## Q3. How many paid apps are there in each category in Descending Order?

# %%
df_pr=df[df['Type']=='Paid']

df_pr.groupby('Category').count()['Type'].sort_values(ascending=False)
# Out:
# Category
# FAMILY                 190
# MEDICAL                109
# GAME                    83
# PERSONALIZATION         82
# TOOLS                   77
# BOOKS_AND_REFERENCE     28
# PRODUCTIVITY            28
# COMMUNICATION           27
# SPORTS                  24
# PHOTOGRAPHY             22
# LIFESTYLE               19
# FINANCE                 17
# HEALTH_AND_FITNESS      16
# BUSINESS                14
# TRAVEL_AND_LOCAL        12
# WEATHER                  8
# DATING                   7
# MAPS_AND_NAVIGATION      5
# EDUCATION                4
# VIDEO_PLAYERS            4
# AUTO_AND_VEHICLES        3
# SOCIAL                   3
# ART_AND_DESIGN           3
# NEWS_AND_MAGAZINES       2
# PARENTING                2
# FOOD_AND_DRINK           2
# SHOPPING                 2
# ENTERTAINMENT            2
# LIBRARIES_AND_DEMO       1
# EVENTS                   1
# Name: Type, dtype: int64
